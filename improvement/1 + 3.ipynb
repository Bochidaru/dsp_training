# %%
# !pip install gdown
# !pip install tensorboardX numpy torch torchvision scikit-image opencv-python h5py matplotlib efficientnet_pytorch einops timm yacs batchgenerators medpy nibabel

# %cd /kaggle/working/
# !rm -rf /kaggle/working/*
# !git clone https://github.com/Bochidaru/dsp_training

import gdown

#https://drive.google.com/file/d/18225R5VrhepZuTJIMGr5X_syFS_NmM66/view?usp=drive_link
file_id = "18225R5VrhepZuTJIMGr5X_syFS_NmM66"  # Replace this with your file's ID
output_file = "data.zip"  # Replace "data_file.ext" with the desired output filename and extension

gdown.download(f"https://drive.google.com/uc?id={file_id}", output_file)

file_id = "16b2paVzOwlk3UOGlDyYsDWmP0ZDza-83"  # Replace this with your file's ID
output_file = "ACDC.zip"  # Replace "data_file.ext" with the desired output filename and extension
gdown.download(f"https://drive.google.com/uc?id={file_id}", output_file)
# !rm -rf /kaggle/working/dsp_training/data/BraTS2019/data
# !unzip -o /kaggle/working/data.zip -d /kaggle/working/dsp_training/data/BraTS2019

# !rm -rf /kaggle/working/dsp_training/data/ACDC/data
# !unzip -o /kaggle/working/ACDC.zip -d /kaggle/working/dsp_training/data
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 8.7 MB/s eta 0:00:00
# ...
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16426 sha256=69423c433692fad605fe256dd129e98463aa581d55f32a14097aa404240f846b
#   Stored in directory: /root/.cache/pip/wheels/9c/3f/43/e6271c7026fe08c185da2be23c98c8e87477d3db63f41f32ad
# ...
#   Created wheel for batchgenerators: filename=batchgenerators-0.25.1-py3-none-any.whl size=93088 sha256=199f103c998bda974943a98ee667f4c5691b5b7eef3c2a0d677d162542ed1cf2
# ...

# %% [markdown]
# **BASE LINE HERE**

# %%
# #baseline
# %cd /kaggle/working/dsp_training/code
# # !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_1 --num_classes 4 --labeled_num 7 --max_iterations 100 & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_2 --num_classes 4 --labeled_num 7 --max_iterations 1000
# # !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_3 --num_classes 4 --labeled_num 7 --max_iterations 100 & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_4 --num_classes 4 --labeled_num 7 --max_iterations 1000

# %%
# %cd /kaggle/working/dsp_training/code
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_1 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_2 --model unet_urpc --num_classes 4 --labeled_num 7
# # !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_3 --model unet_urpc --num_classes 4 --labeled_num 7
# # !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_4 --model unet_urpc --num_classes 4 --labeled_num 7

# %% [markdown]
# [0.78677493 6.57883839 1.84378144]
#
# [0.78151602 5.54293282 1.64495548]

# %% [markdown]
# <h3>1st improvement</h3>

# %%
# %cd /kaggle/working/dsp_training/code
# !CUDA_VISIBLE_DEVICES=0 python "train_uncertainty_rectified_pyramid_consistency_2D - 1st improvement.py" --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_1 --num_classes 4 --labeled_num 7 --max_iterations 10000 & CUDA_VISIBLE_DEVICES=1 python "train_uncertainty_rectified_pyramid_consistency_2D - 1st improvement.py" --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_2 --num_classes 4 --labeled_num 7 --max_iterations 10000
# !CUDA_VISIBLE_DEVICES=0 python "train_uncertainty_rectified_pyramid_consistency_2D - 1st improvement.py" --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_3 --num_classes 4 --labeled_num 7 --max_iterations 10000 & CUDA_VISIBLE_DEVICES=1 python "train_uncertainty_rectified_pyramid_consistency_2D - 1st improvement.py" --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_4 --num_classes 4 --labeled_num 7 --max_iterations 10000
# Out:
# /kaggle/working/dsp_training/code
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
# %cd /kaggle/working/dsp_training/code
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_1 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_2 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_3 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_4 --model unet_urpc --num_classes 4 --labeled_num 7
# Out:
# /kaggle/working/dsp_training/code
# /kaggle/working/dsp_training/code/test_2D_fully.py:12: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
import numpy as np

metric = [0.80528187, 0.79445196, 0.81656161, 0.80696926]
mean_value = np.mean(metric)
mean_value
# Out:
# np.float64(0.8058161749999999)

# %% [markdown]
# <h3>focal loss only</h3>

# %%
# %cd /kaggle/working/dsp_training/code
# !CUDA_VISIBLE_DEVICES=0 python "train_uncertainty_rectified_pyramid_consistency_2D - Only Focal.py" --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_1 --num_classes 4 --labeled_num 7 --max_iterations 10000 & CUDA_VISIBLE_DEVICES=1 python "train_uncertainty_rectified_pyramid_consistency_2D - Only Focal.py" --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_2 --num_classes 4 --labeled_num 7 --max_iterations 10000
# !CUDA_VISIBLE_DEVICES=0 python "train_uncertainty_rectified_pyramid_consistency_2D - Only Focal.py" --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_3 --num_classes 4 --labeled_num 7 --max_iterations 10000 & CUDA_VISIBLE_DEVICES=1 python "train_uncertainty_rectified_pyramid_consistency_2D - Only Focal.py" --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_4 --num_classes 4 --labeled_num 7 --max_iterations 10000
# Out:
# /kaggle/working/dsp_training/code
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
# %cd /kaggle/working/dsp_training/code
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_1 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_2 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_3 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_4 --model unet_urpc --num_classes 4 --labeled_num 7
# Out:
# /kaggle/working/dsp_training/code
# /kaggle/working/dsp_training/code/test_2D_fully.py:12: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
import numpy as np

metric = [0.83617355, 0.83736499, 0.84537867, 0.8402866]
mean_value = np.mean(metric)
mean_value
# Out:
# np.float64(0.8398009525000001)
